# %%
# diffusers>=0.30.1
# transformers>=0.44.0
# accelerate>=0.33.0 (suggest install from source)
# imageio-ffmpeg>=0.5.1
# %pip install --upgrade transformers accelerate diffusers imageio-ffmpeg
# Out:
# Requirement already satisfied: transformers in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (4.47.1)
# Collecting accelerate
#   Downloading accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: diffusers in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (0.32.1)
# Collecting imageio-ffmpeg
#   Downloading imageio_ffmpeg-0.5.1-py3-none-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: filelock in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from accelerate) (6.1.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from accelerate) (2.4.1+cu118)
# Requirement already satisfied: importlib-metadata in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from diffusers) (8.5.0)
# Requirement already satisfied: Pillow in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from diffusers) (10.2.0)
# Requirement already satisfied: setuptools in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from imageio-ffmpeg) (75.1.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: sympy in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: colorama in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from importlib-metadata->diffusers) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\tku-staff\anaconda3\envs\pytorch\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-1.2.1-py3-none-any.whl (336 kB)
# Downloading imageio_ffmpeg-0.5.1-py3-none-win_amd64.whl (22.6 MB)
#    ---------------------------------------- 0.0/22.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/22.6 MB ? eta -:--:--
#     --------------------------------------- 0.5/22.6 MB ? eta -:--:--
#    - -------------------------------------- 1.0/22.6 MB 2.6 MB/s eta 0:00:09
#    -- ------------------------------------- 1.6/22.6 MB 2.3 MB/s eta 0:00:10
#    --- ------------------------------------ 1.8/22.6 MB 2.2 MB/s eta 0:00:10
#    --- ------------------------------------ 2.1/22.6 MB 1.9 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.4/22.6 MB 2.0 MB/s eta 0:00:11
#    ---- ----------------------------------- 2.6/22.6 MB 1.9 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.9/22.6 MB 1.8 MB/s eta 0:00:11
#    ----- ---------------------------------- 3.1/22.6 MB 1.8 MB/s eta 0:00:12
#    ------ --------------------------------- 3.4/22.6 MB 1.7 MB/s eta 0:00:12
#    ------ --------------------------------- 3.7/22.6 MB 1.7 MB/s eta 0:00:12
#    ------- -------------------------------- 4.2/22.6 MB 1.6 MB/s eta 0:00:12
#    ------- -------------------------------- 4.5/22.6 MB 1.6 MB/s eta 0:00:12
#    -------- ------------------------------- 4.7/22.6 MB 1.6 MB/s eta 0:00:12
#    -------- ------------------------------- 5.0/22.6 MB 1.6 MB/s eta 0:00:12
#    -------- ------------------------------- 5.0/22.6 MB 1.6 MB/s eta 0:00:12
#    --------- ------------------------------ 5.5/22.6 MB 1.6 MB/s eta 0:00:11
#    ---------- ----------------------------- 5.8/22.6 MB 1.5 MB/s eta 0:00:12
#    ---------- ----------------------------- 6.0/22.6 MB 1.5 MB/s eta 0:00:12
#    ----------- ---------------------------- 6.3/22.6 MB 1.5 MB/s eta 0:00:12
#    ----------- ---------------------------- 6.3/22.6 MB 1.5 MB/s eta 0:00:12
#    ----------- ---------------------------- 6.6/22.6 MB 1.4 MB/s eta 0:00:12
#    ----------- ---------------------------- 6.6/22.6 MB 1.4 MB/s eta 0:00:12
#    ------------ --------------------------- 6.8/22.6 MB 1.4 MB/s eta 0:00:12
#    ------------ --------------------------- 6.8/22.6 MB 1.4 MB/s eta 0:00:12
#    ------------ --------------------------- 7.1/22.6 MB 1.3 MB/s eta 0:00:13
#    ------------ --------------------------- 7.1/22.6 MB 1.3 MB/s eta 0:00:13
#    ------------ --------------------------- 7.1/22.6 MB 1.3 MB/s eta 0:00:13
#    ------------ --------------------------- 7.3/22.6 MB 1.2 MB/s eta 0:00:13
#    ------------ --------------------------- 7.3/22.6 MB 1.2 MB/s eta 0:00:13
#    ------------ --------------------------- 7.3/22.6 MB 1.2 MB/s eta 0:00:13
#    ------------- -------------------------- 7.6/22.6 MB 1.1 MB/s eta 0:00:14
#    ------------- -------------------------- 7.6/22.6 MB 1.1 MB/s eta 0:00:14
#    ------------- -------------------------- 7.6/22.6 MB 1.1 MB/s eta 0:00:14
#    ------------- -------------------------- 7.9/22.6 MB 1.1 MB/s eta 0:00:14
#    ------------- -------------------------- 7.9/22.6 MB 1.1 MB/s eta 0:00:14
#    -------------- ------------------------- 8.1/22.6 MB 1.0 MB/s eta 0:00:14
#    -------------- ------------------------- 8.1/22.6 MB 1.0 MB/s eta 0:00:14
#    -------------- ------------------------- 8.1/22.6 MB 1.0 MB/s eta 0:00:14
#    -------------- ------------------------- 8.4/22.6 MB 1.0 MB/s eta 0:00:15
#    -------------- ------------------------- 8.4/22.6 MB 1.0 MB/s eta 0:00:15
#    -------------- ------------------------- 8.4/22.6 MB 1.0 MB/s eta 0:00:15
#    --------------- ------------------------ 8.7/22.6 MB 967.3 kB/s eta 0:00:15
#    --------------- ------------------------ 8.7/22.6 MB 967.3 kB/s eta 0:00:15
#    --------------- ------------------------ 8.7/22.6 MB 967.3 kB/s eta 0:00:15
#    --------------- ------------------------ 8.9/22.6 MB 935.2 kB/s eta 0:00:15
#    --------------- ------------------------ 8.9/22.6 MB 935.2 kB/s eta 0:00:15
#    ---------------- ----------------------- 9.2/22.6 MB 912.6 kB/s eta 0:00:15
#    ---------------- ----------------------- 9.2/22.6 MB 912.6 kB/s eta 0:00:15
#    ---------------- ----------------------- 9.2/22.6 MB 912.6 kB/s eta 0:00:15
#    ---------------- ----------------------- 9.4/22.6 MB 891.0 kB/s eta 0:00:15
#    ---------------- ----------------------- 9.4/22.6 MB 891.0 kB/s eta 0:00:15
#    ----------------- ---------------------- 9.7/22.6 MB 872.8 kB/s eta 0:00:15
#    ----------------- ---------------------- 9.7/22.6 MB 872.8 kB/s eta 0:00:15
#    ----------------- ---------------------- 9.7/22.6 MB 872.8 kB/s eta 0:00:15
#    ----------------- ---------------------- 10.0/22.6 MB 858.6 kB/s eta 0:00:15
#    ----------------- ---------------------- 10.0/22.6 MB 858.6 kB/s eta 0:00:15
#    ------------------ --------------------- 10.2/22.6 MB 847.8 kB/s eta 0:00:15
#    ------------------ --------------------- 10.2/22.6 MB 847.8 kB/s eta 0:00:15
#    ------------------ --------------------- 10.5/22.6 MB 834.6 kB/s eta 0:00:15
#    ------------------ --------------------- 10.5/22.6 MB 834.6 kB/s eta 0:00:15
/s eta 0:00:01
#    -------------------------------------- - 22.0/22.6 MB 650.7 kB/s eta 0:00:01
#    ---------------------------------------  22.3/22.6 MB 647.6 kB/s eta 0:00:01
#    ---------------------------------------  22.3/22.6 MB 647.6 kB/s eta 0:00:01
#    ---------------------------------------- 22.6/22.6 MB 640.7 kB/s eta 0:00:00
# Installing collected packages: imageio-ffmpeg, accelerate
# Successfully installed accelerate-1.2.1 imageio-ffmpeg-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from diffusers import CogVideoXPipeline
from diffusers.utils import export_to_video

prompt = "A panda, dressed in a small, red jacket and a tiny hat, sits on a wooden stool in a serene bamboo forest. The panda's fluffy paws strum a miniature acoustic guitar, producing soft, melodic tunes. Nearby, a few other pandas gather, watching curiously and some clapping in rhythm. Sunlight filters through the tall bamboo, casting a gentle glow on the scene. The panda's face is expressive, showing concentration and joy as it plays. The background includes a small, flowing stream and vibrant green foliage, enhancing the peaceful and magical atmosphere of this unique musical performance."

pipe = CogVideoXPipeline.from_pretrained(
    "THUDM/CogVideoX-2b",
    torch_dtype=torch.float16
)

pipe.enable_model_cpu_offload()
pipe.enable_sequential_cpu_offload()
pipe.vae.enable_slicing()
pipe.vae.enable_tiling()
video = pipe(
    prompt=prompt,
    num_videos_per_prompt=1,
    num_inference_steps=50,
    num_frames=49,
    guidance_scale=6,
    generator=torch.Generator(device="cuda").manual_seed(42),
).frames[0]

export_to_video(video, "output.mp4", fps=8)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 7
#       3 from diffusers.utils import export_to_video
#       5 prompt = "A panda, dressed in a small, red jacket and a tiny hat, sits on a wooden stool in a serene bamboo forest. The panda's fluffy paws strum a miniature acoustic guitar, producing soft, melodic tunes. Nearby, a few other pandas gather, watching curiously and some clapping in rhythm. Sunlight filters through the tall bamboo, casting a gentle glow on the scene. The panda's face is expressive, showing concentration and joy as it plays. The background includes a small, flowing stream and vibrant green foliage, enhancing the peaceful and magical atmosphere of this unique musical performance."
# ----> 7 pipe = CogVideoXPipeline.from_pretrained(
#       8     "THUDM/CogVideoX-2b",
#       9     torch_dtype=torch.float16
#      10 )
#      12 pipe.enable_model_cpu_offload()
#      13 pipe.enable_sequential_cpu_offload()
#
# File c:\Users\TKU-STAFF\anaconda3\envs\pytorch\lib\site-packages\diffusers\utils\dummy_torch_and_transformers_objects.py:332, in CogVideoXPipeline.from_pretrained(cls, *args, **kwargs)
#     330 @classmethod
#     331 def from_pretrained(cls, *args, **kwargs):
# --> 332     requires_backends(cls, ["torch", "transformers"])
#
# File c:\Users\TKU-STAFF\anaconda3\envs\pytorch\lib\site-packages\diffusers\utils\import_utils.py:670, in requires_backends(obj, backends)
#     668 failed = [msg.format(name) for available, msg in checks if not available()]
#     669 if failed:
# --> 670     raise ImportError("".join(failed))
#     672 if name in [
#     673     "VersatileDiffusionTextToImagePipeline",
#     674     "VersatileDiffusionPipeline",
#    (...)
#     677     "UnCLIPPipeline",
#     678 ] and is_transformers_version("<", "4.25.0"):
#     679     raise ImportError(
#     680         f"You need to install `transformers>=4.25` in order to use {name}: \n```\n pip install"
#     681         " --upgrade transformers \n```"
#     682     )
#
# ImportError:
# CogVideoXPipeline requires the transformers library but it was not found in your environment. You can install it with pip: `pip
# install transformers`
